# %%
import os

# %%
pathEn = "/Users/kram/Downloads/botOrNot-en_es/es"

# %%
import pandas as pd
import xml.etree.ElementTree as ET
import io
testfile = "/Users/kram/Downloads/botOrNot-en_es/es/1abac92163c7c4a410dad56c8feb7f18.xml"

def iter_docs(author):
    '''This function extracts the text and the language from the XML'''
    author_attr = author.attrib
    for doc in author.iter('document'):
        doc_dict = author_attr.copy()
        doc_dict.update(doc.attrib)
        doc_dict['data'] = doc.text
        yield doc_dict

xml_data = open(testfile, "r") # Opening the text file
etree = ET.parse(xml_data) # Create an ElementTree object 
df = pd.DataFrame(list(iter_docs(etree.getroot()))) #Append the info to a pandas dataframe

# %%
# Getting ID to insert in the dataframe

filename = testfile.split("/")[-1].split(".")[0]

# %%
import time

# Creating empty dataframe
dataEn = pd.DataFrame()

# Monitoring time to load the files
start = time.time()

for root, dirs, files in os.walk(pathEn):
    for file in files:
        if file == 'truth.txt':
            continue
        else: 
            try:
                pathToFile = root + '/' + file # Creating path
                # print(pathToFile) # Just for debugging
                xml_data = open(pathToFile, "r", encoding="utf8") # Opening the text file
                etree = ET.parse(xml_data) # Create an ElementTree object
                data = list(iter_docs(etree.getroot())) # Create a list of dictionaries with the data
                filename = file.split(".")[0] # Get filename
                for dictionary in data: # Loop through the dictionary
                    dictionary['ID'] = filename # Append filename
                dataEn = dataEn.append(data)  # Append the list of dictionary to a pandas dataframe
                
            # If the file is not valid, skip it
            except ValueError as e:
                print(e)
                continue
            
end = time.time()
print("Total running time is", end - start)
# Out:
# Total running time is 41.43629479408264

# %%
pathToLabels = "/Users/kram/Downloads/botOrNot-en_es/es/truth.txt"

# %%
target = pd.read_csv(pathToLabels, sep=":::")
target.columns=['ID', 'botOrHuman', 'sex']
# Out:
# /Users/kram/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
mergedEnData = pd.merge(dataEn, target, on='ID')

# %%
dataEn
# Out:
#                                   ID  \
# 0   3528ef91c7484ec189dcc82a7f9cd613
# 1   3528ef91c7484ec189dcc82a7f9cd613
# 2   3528ef91c7484ec189dcc82a7f9cd613
# 3   3528ef91c7484ec189dcc82a7f9cd613
# 4   3528ef91c7484ec189dcc82a7f9cd613
# 5   3528ef91c7484ec189dcc82a7f9cd613
# 6   3528ef91c7484ec189dcc82a7f9cd613
# 7   3528ef91c7484ec189dcc82a7f9cd613
# 8   3528ef91c7484ec189dcc82a7f9cd613
# 9   3528ef91c7484ec189dcc82a7f9cd613
# 10  3528ef91c7484ec189dcc82a7f9cd613
# 11  3528ef91c7484ec189dcc82a7f9cd613
# 12  3528ef91c7484ec189dcc82a7f9cd613
# 13  3528ef91c7484ec189dcc82a7f9cd613
# 14  3528ef91c7484ec189dcc82a7f9cd613
# 15  3528ef91c7484ec189dcc82a7f9cd613
# 16  3528ef91c7484ec189dcc82a7f9cd613
# 17  3528ef91c7484ec189dcc82a7f9cd613
# 18  3528ef91c7484ec189dcc82a7f9cd613
# 13  #Hollywood 💫 @ Hollywood Sign View Point https...   es
# 14  After all this time? A L W A Y S ⚡️ @ TCL Chin...   es
# 15  Sumando momentos 💙💜💚 #BeverlyHills 🌻 No hay eq...   es
# 16  Mi lugar favorito... #Hogwarts 💛✨ No puedo dis...   es
# 17  Sunset in Santa Mónica 🌇🎢🎡 #SanaMonicaParaLosA...   es
# 18  #LasVegas ✨🏙 @ Las Vegas Welcome Sign https://...   es
# 19  Hoy y mañana... #LasVegas ✨🌃 @ Las Vegas, Neva...   es
# 20  Ayer estuvimos en Malibú 🌴☀️ y pudimos ver una...   es
# 21      Os amo 💙💜💚 A Fuego 🔥🍀 https://t.co/VhzeHUWSgn   es
# 22                        😄🔥🍀 https://t.co/Ct9Gf8qUor   es
# 23    @PartidoPACMA @AzaharaySiria digno de difundir!   es
# 24  RT @PartidoPACMA: #CineSíTorosNO 80.000 firmas...   es
# 25  RT @pacoleonbarrios: Un gobierno que no identi...   es
# 26  RT @defenpal: Ayuda con tu RT a #ROMEO. Necesi...   es
# 27  RT @DifIris: Venus\nMes y medio, 1 kilo\nSerá ...   es
# 28  RT @femisaurio: "SE TE VE EL SUJETADOR"\n\nval...   es
# 29  Y una pequeña mariquita apareció 🐞💛 https://t....   es
# ..                                                ...  ...
# 70  I: ¨Eso es lo que quiero, al menos en ese tiem...   es
# 71  De Calamaro a Cerati, una noche feeling. Y ahí...   es
# 72  Voy a salir a caminar solita sentarme en un pa...   es
# 73  Y hay personas q conoces, y t alegran el día, ...   es
# 74  de paso exponer su seguridad y el bolsillo bus...   es
# 75  Que importa la noche, el día, las plantas, las...   es
# 76  Agregué un video a una lista de reproducción d...   es
# 77  Agregué un video a una lista de reproducción d...   es
# 78  Agregué un video a una lista de reproducción d...   es
# 79  Agregué un video a una lista de reproducción d...   es
# 80  Agregué un video a una lista de reproducción d...   es
# 81  Agregué un video a una lista de reproducción d...   es
# 82  Agregué un video a una lista de reproducción d...   es
# 83  Agregué un video a una lista de reproducción d...   es
# 84  RT @DatoDeNutricion: Un tigre no pierde su sue...   es
# 85  RT @GenialesFotos: Venecia. http://t.co/n6hikK...   es
# 86  ¨Me caen mal las personas que aparentan. Me ca...   es
# 87  http://t.co/zQh9rg2V El lago de los cisnes. Un...   es
# 88  http://t.co/vpwk2Ui5 owww Claro de luna Beetho...   es
# 89  http://t.co/6bLdwean Estudiando con música clá...   es
# 90  RT @luisiberico: OHT: sobre economía repite fr...   es
# 91  omg..! me esta gustando trabajar los domingos....   es
# 92  RT @CunaMasPeru: #FamiliaMIDIS Todos los días ...   es
# 93  Lo que fue mi fin de semana. 😊😍👫💕 #withhim #wi...   es
# 94  RT @GramaticaReal: Ser bueno es el único modo ...   es
# 95  RT @BorgesJorgeL: La educación no es un instru...   es
# 96  RT @iPrincipito: Tú tendrás estrellas como nad...   es
# 97  RT @eligeeducar: Niños bajan hasta tres décima...   es
# 299889  be816cd346d9260a2d6f53cde0b24141
# 299890  be816cd346d9260a2d6f53cde0b24141
# 299891  be816cd346d9260a2d6f53cde0b24141
# 299892  be816cd346d9260a2d6f53cde0b24141
# 299893  be816cd346d9260a2d6f53cde0b24141
# 299894  be816cd346d9260a2d6f53cde0b24141
# 299895  be816cd346d9260a2d6f53cde0b24141
# 299896  be816cd346d9260a2d6f53cde0b24141
# 299897  be816cd346d9260a2d6f53cde0b24141
# 299898  be816cd346d9260a2d6f53cde0b24141
# 299899  be816cd346d9260a2d6f53cde0b24141
#
#                                                      data lang botOrHuman  \
# 0       RT @Stoneismynamee: Si me queréis ganar en San...   es      human
# 1       RT @amor_animal015: Choco aún no tiene adopció...   es      human
# 2       RT @yisucrist: cuando t enteras d k tu humano ...   es      human
# 3       RT @A3Noticias: La técnica del 'bodypainting' ...   es      human
# 4       RT @yisucrist: stoi yorando https://t.co/0uSb1...   es      human
# 5       @FrankieJesstein @IanVanXanten ay dios, tiene ...   es      human
# 6             Just posted a photo https://t.co/zcoGd0JnAm   es      human
# 7       RT @A3Noticias: Una hembra de labrador color c...   es      human
# 8       RT @Vertele: Daniel Guzmán, el que faltaba por...   es      human
# 9       RT @adoptaunavidaMD: KIMI, este zorro blanco, ...   es      human
# 10      RT @A3Noticias: Una azafata salva en pleno vue...   es      human
# 11      RT @A3Noticias: VÍDEO ▶ Cientos de personas sa...   es      human
# 12      RT @lavecinarubia: La mejor vestida de los #Go...   es      human
# 13      #Hollywood 💫 @ Hollywood Sign View Point https...   es      human
# 14      After all this time? A L W A Y S ⚡️ @ TCL Chin...   es      human
# 15      Sumando momentos 💙💜💚 #BeverlyHills 🌻 No hay eq...   es      human
# 16      Mi lugar favorito... #Hogwarts 💛✨ No puedo dis...   es      human
# 17      Sunset in Santa Mónica 🌇🎢🎡 #SanaMonicaParaLosA...   es      human
# 18      #LasVegas ✨🏙 @ Las Vegas Welcome Sign https://...   es      human
# 19      Hoy y mañana... #LasVegas ✨🌃 @ Las Vegas, Neva...   es      human
# 20      Ayer estuvimos en Malibú 🌴☀️ y pudimos ver una...   es      human
# 21          Os amo 💙💜💚 A Fuego 🔥🍀 https://t.co/VhzeHUWSgn   es      human
# 22                            😄🔥🍀 https://t.co/Ct9Gf8qUor   es      human
# 23        @PartidoPACMA @AzaharaySiria digno de difundir!   es      human
# 24      RT @PartidoPACMA: #CineSíTorosNO 80.000 firmas...   es      human
# 25      RT @pacoleonbarrios: Un gobierno que no identi...   es      human
# 26      RT @defenpal: Ayuda con tu RT a #ROMEO. Necesi...   es      human
# 27      RT @DifIris: Venus\nMes y medio, 1 kilo\nSerá ...   es      human
# 28      RT @femisaurio: "SE TE VE EL SUJETADOR"\n\nval...   es      human
# 29      Y una pequeña mariquita apareció 🐞💛 https://t....   es      human
# ...                                                   ...  ...        ...
# 299870  I: ¨Eso es lo que quiero, al menos en ese tiem...   es      human
# 299871  De Calamaro a Cerati, una noche feeling. Y ahí...   es      human
# 299872  Voy a salir a caminar solita sentarme en un pa...   es      human
# 299873  Y hay personas q conoces, y t alegran el día, ...   es      human
# 299874  de paso exponer su seguridad y el bolsillo bus...   es      human
# 299875  Que importa la noche, el día, las plantas, las...   es      human
# 299876  Agregué un video a una lista de reproducción d...   es      human
# 299877  Agregué un video a una lista de reproducción d...   es      human
# 299878  Agregué un video a una lista de reproducción d...   es      human
# 299879  Agregué un video a una lista de reproducción d...   es      human
# 299880  Agregué un video a una lista de reproducción d...   es      human
# 299881  Agregué un video a una lista de reproducción d...   es      human
# 299882  Agregué un video a una lista de reproducción d...   es      human
# 299883  Agregué un video a una lista de reproducción d...   es      human
# 299884  RT @DatoDeNutricion: Un tigre no pierde su sue...   es      human
# 299885  RT @GenialesFotos: Venecia. http://t.co/n6hikK...   es      human
# 299886  ¨Me caen mal las personas que aparentan. Me ca...   es      human
# 299887  http://t.co/zQh9rg2V El lago de los cisnes. Un...   es      human
# 299888  http://t.co/vpwk2Ui5 owww Claro de luna Beetho...   es      human
# 299889  http://t.co/6bLdwean Estudiando con música clá...   es      human
# 299890  RT @luisiberico: OHT: sobre economía repite fr...   es      human
# 299891  omg..! me esta gustando trabajar los domingos....   es      human
# 299892  RT @CunaMasPeru: #FamiliaMIDIS Todos los días ...   es      human
# 299893  Lo que fue mi fin de semana. 😊😍👫💕 #withhim #wi...   es      human
# 299894  RT @GramaticaReal: Ser bueno es el único modo ...   es      human
# 299895  RT @BorgesJorgeL: La educación no es un instru...   es      human
# 299896  RT @iPrincipito: Tú tendrás estrellas como nad...   es      human
# 299897  RT @eligeeducar: Niños bajan hasta tres décima...   es      human
# 299898  RT @sergionicr: Somos de quien nos hace su pri...   es      human
# 299899  RT @iPrincipito: Donde te sientas feliz, ahí e...   es      human
#
#            sex
# 0       female
# 1       female
# 2       female
# 3       female
# 4       female
# 5       female
# 6       female
# 7       female
# 8       female
# 9       female
# 10      female
# 11      female
# 12      female
# 13      female
# 14      female
# 15      female
# 16      female
# 17      female
# 18      female
# 19      female
# 20      female
# 21      female
# 22      female
# 23      female
# 24      female
# 25      female
# 26      female
# 27      female
# 28      female
# 29      female
# ...        ...
# 299870  female
# 299871  female
# 299872  female
# 299873  female
# 299874  female
# 299875  female
# 299876  female
# 299877  female
# 299878  female
# 299879  female
# 299880  female
# 299881  female
# 299882  female
# 299883  female
# 299884  female
# 299885  female
# 299886  female
# 299887  female
# 299888  female
# 299889  female
# 299890  female
# 299891  female
# 299892  female
# 299893  female
# 299894  female
# 299895  female
# 299896  female
# 299897  female
# 299898  female
# 299899  female
#
# [150000 rows x 5 columns]

# %%
pathEn = '/Volumes/MacPassport/PycharmProjects/botOrNot/genHuman/es'
import time

# Creating empty dataframe
dataEn2 = pd.DataFrame()

# Monitoring time to load the files
start = time.time()

for root, dirs, files in os.walk(pathEn):
    for file in files:
        if file == 'truth.csv':
            continue
        else: 
            try:
                pathToFile = root + '/' + file # Creating path
                # print(pathToFile) # Just for debugging
                xml_data = open(pathToFile, "r", encoding="utf8") # Opening the text file
               
                etree = ET.parse(xml_data) # Create an ElementTree object
                
                data = list(iter_docs(etree.getroot())) # Create a list of dictionaries with the data
                filename = file.split(".")[0] # Get filename
                for dictionary in data: # Loop through the dictionary
                    dictionary['ID'] = filename # Append filename
                dataEn2 = dataEn2.append(data)  # Append the list of dictionary to a pandas dataframe
                
            # If the file is not valid, skip it
            except ValueError as e:
                print(e)
                continue
            
end = time.time()
print("Total running time is", end - start)

# %%
pathToLabels = "/Volumes/MacPassport/PycharmProjects/botOrNot/genHuman/en/truth.csv"

# %%
target = pd.read_csv(pathToLabels, sep=":::", header = None)
target.columns=['ID', 'botOrHuman', 'sex']

# %%
mergedEnData2 = pd.merge(dataEn2, target, on='ID')

# %%
mergedEnData2

# %%
#Creo le matrici

# %%
'''Creo la litsa degli ID, delle classi e dei tweets pr ogni ID'''

listaIds =[]
listaClasses = []
matrixTweets = []

for index, x in mergedEnData.iterrows():
    id = x['ID']
    if id not in listaIds:
        newList = list()
        newList.append(x[1])
        matrixTweets.append(newList)
        listaIds.append(id)
        listaClasses.append(x[4])
    else:
        ls = matrixTweets[listaIds.index(id)]
        ls.append(x[1])
        matrixTweets[listaIds.index(id)] = ls
        
print(len(listaIds))
# Out:
# 1500

# %%
listaIds2 =[]
listaClasses2 = []
matrixTweets2 = []

for index, x in mergedEnData2.iterrows():
    id = x['ID']
    if id not in listaIds2:
        newList = list()
        newList.append(x[1])
        matrixTweets2.append(newList)
        listaIds2.append(id)
        listaClasses2.append(x[4])
    else:
        ls = matrixTweets2[listaIds2.index(id)]
        ls.append(x[1])
        matrixTweets2[listaIds2.index(id)] = ls
        
print(len(listaIds2))
print(len(matrixTweets2))

# %%
from ekphrasis.dicts.emoticons import emoticons
from ekphrasis.classes.preprocessor import TextPreProcessor
from ekphrasis.classes.tokenizer import SocialTokenizer

text_processor = TextPreProcessor (
    # terms that will be normalized
    normalize=[ 'email' , 'percent' , 'money' , 'phone' ,
                'time' , 'url' , 'date' , 'number' ] ,
    fix_html=True ,  # fix HTML tokens
    segmenter="twitter" ,
    corrector="twitter" ,
    unpack_hashtags=True ,  # perform word segmentation on hashtags
    unpack_contractions=False ,  # Unpack contractions (can't -> can not)
    spell_correct_elong=False ,  # spell correction for elongated words
    tokenizer=SocialTokenizer(lowercase=True).tokenize,
    dicts=[ emoticons ]
)
# Out:
# Reading twitter - 1grams ...
# Reading twitter - 2grams ...
# Reading twitter - 1grams ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(matrixTweets, listaClasses, test_size = 0.10, random_state=72753)

# %%
import numpy as np
X_train = np.concatenate([X_train,matrixTweets2])
y_train = np.concatenate([y_train,listaClasses2])

# %%
len(X_train)
len(y_train)

# %%
import gensim
google_300 = gensim.models.KeyedVectors.load_word2vec_format("/Volumes/MacPassport/PycharmProjects/botOrNot/cc.es.300.vec")

# %%
from nltk.tokenize import TweetTokenizer as TweetTokenizer
from nltk.corpus import stopwords
import random as rn
import numpy as np
stop_words = set(stopwords.words('spanish'))
i = 0
matrixTweetsEmb_train = []
for tweetsUser in X_train:
    embTweetsUser = []
    if(i % 100) == 0:
         print(i)
    for tweet in tweetsUser:
        embTweetUser = np.zeros([50,300])
        #Preprocesso
        tokList = text_processor.pre_process_doc(tweet)
        #Rimuovo le stopwords
        tokList = [w for w in tokList if not w in stop_words]
        #trovo l'embedding
        numTok = 0;
        for token in tokList[0:50]:
            g_vec =[]
            is_in_model = False
            if token in google_300.vocab.keys ( ):
                is_in_model = True
                g_vec = google_300.word_vec(token)
            elif token == "<number>":
                is_in_model = True
                g_vec = google_300.word_vec( "número")
            elif token == "<percent>":
                is_in_model = True
                g_vec = google_300.word_vec("porcentaje")
            elif token == "<money>":
                is_in_model = True
                g_vec = google_300.word_vec("dinero")
            elif token == "<email>":
                is_in_model = True
                g_vec = google_300.word_vec("email")
            elif token == "<phone>":
                is_in_model = True
                g_vec = google_300.word_vec("teléfono")
            elif token == "<time>":
                is_in_model = True
                g_vec = google_300.word_vec("hora")
            elif token == "<date>":
                is_in_model = True
                g_vec = google_300.word_vec("fecha")
            elif token == "<url>":
                is_in_model = True
                g_vec = google_300.word_vec("link")
            elif not is_in_model:
                max = len ( google_300.vocab.keys ( ) ) - 1
                index = rn.randint ( 0 , max )
                word = google_300.index2word[ index ]
                g_vec = google_300.word_vec( word )
            embTweetUser[numTok] = np.array(g_vec)
            numTok += 1
        embTweetsUser.append(np.array(embTweetUser))
    i +=1
    matrixTweetsEmb_train.append(np.array(embTweetsUser))
matrixTweetsEmb_train = np.array(matrixTweetsEmb_train)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300

# %%
i = 0
matrixTweetsEmb_test = []
for tweetsUser in X_test:
    embTweetsUser = []
    if(i % 100) == 0:
         print(i)
    for tweet in tweetsUser:
        embTweetUser = np.zeros([50,300])
        #Preprocesso
        tokList = text_processor.pre_process_doc(tweet)
        #Rimuovo le stopwords
        tokList = [w for w in tokList if not w in stop_words]
        #trovo l'embedding
        numTok = 0;
        for token in tokList[0:50]:
            g_vec =[]
            is_in_model = False
            if token in google_300.vocab.keys ( ):
                is_in_model = True
                g_vec = google_300.word_vec(token)
            elif token == "<number>":
                is_in_model = True
                g_vec = google_300.word_vec( "número")
            elif token == "<percent>":
                is_in_model = True
                g_vec = google_300.word_vec("porcentaje")
            elif token == "<money>":
                is_in_model = True
                g_vec = google_300.word_vec("dinero")
            elif token == "<email>":
                is_in_model = True
                g_vec = google_300.word_vec("email")
            elif token == "<phone>":
                is_in_model = True
                g_vec = google_300.word_vec("teléfono")
            elif token == "<time>":
                is_in_model = True
                g_vec = google_300.word_vec("hora")
            elif token == "<date>":
                is_in_model = True
                g_vec = google_300.word_vec("fecha")
            elif token == "<url>":
                is_in_model = True
                g_vec = google_300.word_vec("link")
            elif not is_in_model:
                max = len ( google_300.vocab.keys ( ) ) - 1
                index = rn.randint ( 0 , max )
                word = google_300.index2word[ index ]
                g_vec = google_300.word_vec( word )

            embTweetUser[numTok] = np.array(g_vec)
            numTok += 1
        embTweetsUser.append(np.array(embTweetUser))
    i +=1
    matrixTweetsEmb_test.append(np.array(embTweetsUser))
matrixTweetsEmb_test = np.array(matrixTweetsEmb_test)
# Out:
# 0
# 100

# %%
from keras.layers import *
from keras.models import Sequential
model = Sequential()
model.add(Conv2D(200,(5,5), activation ='relu', input_shape=(100,50,300)))
model.add(MaxPool2D(2,2))
model.add(Conv2D(100,(5,4), activation ='relu'))
model.add(MaxPool2D(2,2))
model.add(Conv2D(20,(3,3), activation ='relu'))
model.add(MaxPool2D(2,2))
model.add(Flatten())
model.add(Dense(400, activation="tanh"))
model.add(Dense(200, activation="tanh"))
model.add(Dense(100, activation="tanh"))
model.add(Dense(2, activation="softmax"))
model.summary()
# Out:
# /Users/kram/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 96, 46, 200)       1500200
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 48, 23, 200)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 44, 20, 100)       400100
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 10, 100)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 8, 20)         18020
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 4, 20)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 800)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 400)               320400
# _________________________________________________________________
# dense_2 (Dense)              (None, 200)               80200
# _________________________________________________________________
# dense_3 (Dense)              (None, 100)               20100
# _________________________________________________________________
# dense_4 (Dense)              (None, 2)                 202
# =================================================================
# Total params: 2,339,222
# Trainable params: 2,339,222
# Non-trainable params: 0
# _________________________________________________________________

# %%
import category_encoders as ce
le =  ce.OneHotEncoder(return_df=False, impute_missing=False, handle_unknown="ignore")
training_classes = le.fit_transform(y_train)
test_classes = le.transform(y_test)
print(le.category_mapping)
# Out:
# [{'col': 0, 'mapping': [('female', 1), ('male', 2)]}]

# %%
from  sklearn.metrics  import classification_report
from keras.callbacks import Callback
class MyCallBack(Callback):
    def __init__(self,verbose=0):

        super(Callback, self).__init__()
        self.verbose = verbose

    def on_epoch_end(self, epoch, logs={}):
        current = logs.get('val_loss')
        # if current < 0.014:
        #     self.model.stop_training = True

        predicted = model.predict( matrixTweetsEmb_test )

        test = [ '0' ] * len ( X_test )
        i = 0
        for cl in predicted:
            test[ i ] = str ( np.argmax ( cl ) )
            i += 1

        test_lab = [ '0' ] * len ( X_test )
        i = 0
        for cl in test_classes:
            test_lab[ i ] = str ( np.argmax ( cl ) )
            i += 1

        print ( len ( X_test ) )
        print ( classification_report ( test , test_lab, digits=5 ) )

# %%
from keras.callbacks import ModelCheckpoint
filepath="/Volumes/MacPassport/PycharmProjects/botOrNot/MF.weights.{epoch:02d}-{val_loss:.5f}-{val_acc:.5f}_fasttext_esp_hb.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

# %%
callbacks_list = [
    checkpoint,
    MyCallBack(verbose=1)
]

# %%
model.compile ( loss='categorical_crossentropy' , optimizer='adam' , metrics=['accuracy'] )

history = model.fit(matrixTweetsEmb_train,training_classes,batch_size=64,epochs=8,
                      validation_data= (matrixTweetsEmb_test,test_classes) ,
                      callbacks=callbacks_list,
                      verbose=1)
# Out:
# Train on 1350 samples, validate on 150 samples
# Epoch 1/8
# 1350/1350 [==============================] - 722s 535ms/step - loss: 0.7290 - acc: 0.5170 - val_loss: 0.7076 - val_acc: 0.5000
#
# Epoch 00001: val_acc improved from -inf to 0.50000, saving model to /Volumes/MacPassport/PycharmProjects/botOrNot/MF.weights.01-0.70759-0.50000_fasttext_esp_hb.hdf5
# 150
#              precision    recall  f1-score   support
#
#           0    0.94286   0.48175   0.63768       137
#           1    0.11250   0.69231   0.19355        13
#
# avg / total    0.87089   0.50000   0.59919       150
#
# Epoch 2/8
# 1350/1350 [==============================] - 727s 538ms/step - loss: 0.6876 - acc: 0.5770 - val_loss: 0.6826 - val_acc: 0.5400
#
# Epoch 00002: val_acc improved from 0.50000 to 0.54000, saving model to /Volumes/MacPassport/PycharmProjects/botOrNot/MF.weights.02-0.68258-0.54000_fasttext_esp_hb.hdf5
# 150
#              precision    recall  f1-score   support
#
#           0    0.07143   0.55556   0.12658         9
#           1    0.95000   0.53901   0.68778       141
#
# avg / total    0.89729   0.54000   0.65411       150
#
# Epoch 3/8
# 1350/1350 [==============================] - 727s 539ms/step - loss: 0.6845 - acc: 0.5533 - val_loss: 0.6600 - val_acc: 0.6467
#
# Epoch 00003: val_acc improved from 0.54000 to 0.64667, saving model to /Volumes/MacPassport/PycharmProjects/botOrNot/MF.weights.03-0.65996-0.64667_fasttext_esp_hb.hdf5
# 150
#              precision    recall  f1-score   support
#
#           0    0.82857   0.58586   0.68639        99
#           1    0.48750   0.76471   0.59542        51
#
# avg / total    0.71261   0.64667   0.65546       150
#
# Epoch 4/8
# 1350/1350 [==============================] - 649s 481ms/step - loss: 0.6472 - acc: 0.6207 - val_loss: 0.7485 - val_acc: 0.5267
#
# Epoch 00004: val_acc did not improve from 0.64667
# 150
#              precision    recall  f1-score   support
#
#           0    0.91429   0.49612   0.64322       129
#           1    0.18750   0.71429   0.29703        21
#
# avg / total    0.81254   0.52667   0.59475       150
#
# Epoch 5/8
# 1350/1350 [==============================] - 807s 598ms/step - loss: 0.5714 - acc: 0.6904 - val_loss: 0.6342 - val_acc: 0.6733
#
# Epoch 00005: val_acc improved from 0.64667 to 0.67333, saving model to /Volumes/MacPassport/PycharmProjects/botOrNot/MF.weights.05-0.63417-0.67333_fasttext_esp_hb.hdf5
# 150
#              precision    recall  f1-score   support
#
#           0    0.78571   0.61798   0.69182        89
#           1    0.57500   0.75410   0.65248        61
#
# avg / total    0.70002   0.67333   0.67582       150
#
# Epoch 6/8
# 1350/1350 [==============================] - 712s 527ms/step - loss: 0.3932 - acc: 0.8274 - val_loss: 0.7031 - val_acc: 0.6800
#
# Epoch 00006: val_acc improved from 0.67333 to 0.68000, saving model to /Volumes/MacPassport/PycharmProjects/botOrNot/MF.weights.06-0.70314-0.68000_fasttext_esp_hb.hdf5
# 150
#              precision    recall  f1-score   support
#
#           0    0.67143   0.65278   0.66197        72
#           1    0.68750   0.70513   0.69620        78
#
# avg / total    0.67979   0.68000   0.67977       150
#
# Epoch 7/8
# 1350/1350 [==============================] - 750s 556ms/step - loss: 0.2092 - acc: 0.9267 - val_loss: 1.0430 - val_acc: 0.6200
#
# Epoch 00007: val_acc did not improve from 0.68000
# 150
#              precision    recall  f1-score   support
#
#           0    0.74286   0.57143   0.64596        91
#           1    0.51250   0.69492   0.58993        59
#
# avg / total    0.65225   0.62000   0.62392       150
#
# Epoch 8/8
#  320/1350 [======>.......................] - ETA: 9:03 - loss: 0.2013 - acc: 0.9156
