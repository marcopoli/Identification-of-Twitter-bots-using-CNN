# %%
import os
os.listdir()
# Out:
# ['twitter_gender.csv.zip',
#  '.DS_Store',
#  'maleOrFemale.ipynb',
#  'botNotBot.ipynb',
#  '02.CNN_100x50x300D_google_0.9693.h5',
#  'matrixTweetsEmb_ALT.dump',
#  'matrixTweetsEmb_FAST2.dump',
#  'google_w2v_300.bin',
#  'botNotBot.py',
#  'gender-classifier-DFE-791531.csv',
#  '02.CNN_100x50x300D_google_0.98.h5',
#  'createMaleFemale_new_examples.py',
#  'Dataset-README',
#  'botOrNot_loadAndFIlter.ipynb',
#  '.ipynb_checkpoints',
#  '01.CNN_100x50x300D_google_0.964.h5',
#  'en',
#  '.git',
#  'listaClasses.dump',
#  '.idea']

# %%
pathEn = "/Users/kram/Downloads/botOrNot-en_es/en"

# %%
import pandas as pd
import xml.etree.ElementTree as ET
import io
testfile = "/Users/kram/Downloads/botOrNot-en_es/en/1a5b808546838869bc39cebdbad951e3.xml"

def iter_docs(author):
    '''This function extracts the text and the language from the XML'''
    author_attr = author.attrib
    for doc in author.iter('document'):
        doc_dict = author_attr.copy()
        doc_dict.update(doc.attrib)
        doc_dict['data'] = doc.text
        yield doc_dict

xml_data = open(testfile, "r") # Opening the text file
etree = ET.parse(xml_data) # Create an ElementTree object 
df = pd.DataFrame(list(iter_docs(etree.getroot()))) #Append the info to a pandas dataframe

# %%
# Getting ID to insert in the dataframe

filename = testfile.split("/")[-1].split(".")[0]

# %%
import time

# Creating empty dataframe
dataEn = pd.DataFrame()

# Monitoring time to load the files
start = time.time()

for root, dirs, files in os.walk(pathEn):
    for file in files:
        if file == 'truth.txt':
            continue
        else: 
            try:
                pathToFile = root + '/' + file # Creating path
                # print(pathToFile) # Just for debugging
                xml_data = open(pathToFile, "r", encoding="utf8") # Opening the text file
                etree = ET.parse(xml_data) # Create an ElementTree object
                data = list(iter_docs(etree.getroot())) # Create a list of dictionaries with the data
                filename = file.split(".")[0] # Get filename
                for dictionary in data: # Loop through the dictionary
                    dictionary['ID'] = filename # Append filename
                dataEn = dataEn.append(data)  # Append the list of dictionary to a pandas dataframe
                
            # If the file is not valid, skip it
            except ValueError as e:
                print(e)
                continue
            
end = time.time()
print("Total running time is", end - start)
# Out:
# Total running time is 62.73006796836853

# %%
pathToLabels = "/Users/kram/Downloads/botOrNot-en_es/en/truth.txt"

# %%
target = pd.read_csv(pathToLabels, sep=":::")
target.columns=['ID', 'botOrHuman', 'sex']
# Out:
# /Users/kram/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
mergedEnData = pd.merge(dataEn, target, on='ID')

# %%
dataEn
# Out:
#                                   ID  \
# 0   867be96f95dfc4e24541d19c6a5ab8bf
# 1   867be96f95dfc4e24541d19c6a5ab8bf
# 2   867be96f95dfc4e24541d19c6a5ab8bf
# 3   867be96f95dfc4e24541d19c6a5ab8bf
# 4   867be96f95dfc4e24541d19c6a5ab8bf
# 5   867be96f95dfc4e24541d19c6a5ab8bf
# 6   867be96f95dfc4e24541d19c6a5ab8bf
# 7   867be96f95dfc4e24541d19c6a5ab8bf
# 8   867be96f95dfc4e24541d19c6a5ab8bf
# 9   867be96f95dfc4e24541d19c6a5ab8bf
# 11  @phil_c_x @karmen1998 @leahmckeanx @glasgow_so...   en
# 12  RT @shallennae: Give yourself 30 minutes to be...   en
# 13                            @lilymacintyre_ Show me   en
# 14  @ionaagriffin @alextluu Mind I stalled the car...   en
# 15               @_amylennie  https://t.co/WIdsPgMcgA   en
# 16                                    @_amylennie Who   en
# 17            @JamieClay_ @karmen1998 @beckyfrancesxo   en
# 18  RT @MassiveMcCann: feel pure shite just want h...   en
# 19  RT @ActuallyGina: *waits 12 minutes to reply a...   en
# 20  RT @jjadebuchanan: Why do shops sell bikini to...   en
# 21  The chase gets me fuckin rajin what a shame on...   en
# 22  RT @xTashaAndersonx: Fuck having pals that jud...   en
# 23                          @alie_jans @elliemcginty1   en
# 24           Just been paid today and still skint 🤣🤣🤣   en
# 25      @glasgow_sophie 😭😭😭 I’ll put a bet on for u x   en
# 26            RT @rregaann: Skint is a understatement   en
# 27  RT @CaitlynLKing: Please RT.. if anybody sees ...   en
# 28         @_amylennie all that red bulls gettin to u   en
# 29  @_amylennie Well that was a bit pervy u big fr...   en
# ..                                                ...  ...
# 70  RT @maurice_ace: @OlaEmdin Answer is because N...   en
# 71  I'm just glad @osi_suave has helped too many p...   en
# 72  Another PR/manager who collects money from art...   en
# 73  Upgraded my ringtone from Ye to Gbona as it sh...   en
# 74  RT @rollybello: This was last year at Eyinni G...   en
# 75  What exactly has the AU achieved in strengthen...   en
# 76  This whole getting a visa to go to Tanzania ha...   en
# 77                                  Praiz - Shomolele   en
# 78  RT @burnaboy: Burna Boy - Gbona (Official Musi...   en
# 79  RT @NoTengoElJugo_: I bet the oxygen there CRI...   en
# 80              Calvin Harris Ft Sam Smith - Promises   en
# 81             RT @kae_y: !!! https://t.co/gl1Bgq9OsA   en
# 82                 RT @cyberrboi: @OlaEmdin Dont dull   en
# 83  RT @maurice_ace: @OlaEmdin Sharp sharp babes n...   en
# 84  RT @MojiDelanoBlog: #FreeBhadoosky: Nigerians ...   en
# 85  Sometimes I feel like I should reconsider this...   en
# 86  RT @MosJollof: We also take orders from 20 pla...   en
# 87  RT @MosJollof: Call and order for your firewoo...   en
# 88  RT @adetutuoj8811: She has followed me on Inst...   en
# 89  This country is about to experience the worst ...   en
# 90  I've been seeing this tweet all day. Lol https...   en
# 91  RT @Deekachy_md: We just lost my friend's mom ...   en
# 92    @jarule147 Seen his new video? It's right there   en
# 93  In my two years of running @MosJollof, this is...   en
# 94  Thick skin should be the only thing required t...   en
# 95  RT @ItsBollyLomo: Btw @MosJollof makes one of ...   en
# 96                      Inauguration day in a bit...😊   en
# 97                The family God blessed me with....❤   en
# 98  RT @sam_adeyemi: This week, you will attract r...   en
# 99  @cyberrboi @ShowDemCamp @MosJollof @MNLNDBlock...   en
#
# [412000 rows x 3 columns]

# %%
mergedEnData = mergedEnData[mergedEnData.botOrHuman == "human"]

# %%
mergedEnData
# Out:
#                                       ID  \
# 0       867be96f95dfc4e24541d19c6a5ab8bf
# 1       867be96f95dfc4e24541d19c6a5ab8bf
# 2       867be96f95dfc4e24541d19c6a5ab8bf
# 3       867be96f95dfc4e24541d19c6a5ab8bf
# 3       @RyanDunbar8 happy bday Ryan have the best day...   en      human
# 4       @jennyhastie @bootywhispers I just wanna let j...   en      human
# 5           @bootywhispers @jennyhastie what would u do ?   en      human
# 6       @Aidsterrr Asking for a mate :/ wee bit line o...   en      human
# 7        Wonder what a Sunday without the fear feels like   en      human
# 8       RT @liamfrenchx: Brutal getn wee flashbacks a ...   en      human
# 9       Went to a&amp;e last night myself after I lock...   en      human
# 10                    @s9kyle @karmen1998 @glasgow_sophie   en      human
# 11      @phil_c_x @karmen1998 @leahmckeanx @glasgow_so...   en      human
# 12      RT @shallennae: Give yourself 30 minutes to be...   en      human
# 13                                @lilymacintyre_ Show me   en      human
# 14      @ionaagriffin @alextluu Mind I stalled the car...   en      human
# 15                   @_amylennie  https://t.co/WIdsPgMcgA   en      human
# 16                                        @_amylennie Who   en      human
# 17                @JamieClay_ @karmen1998 @beckyfrancesxo   en      human
# 18      RT @MassiveMcCann: feel pure shite just want h...   en      human
# 19      RT @ActuallyGina: *waits 12 minutes to reply a...   en      human
# 20      RT @jjadebuchanan: Why do shops sell bikini to...   en      human
# 21      The chase gets me fuckin rajin what a shame on...   en      human
# 22      RT @xTashaAndersonx: Fuck having pals that jud...   en      human
# 23                              @alie_jans @elliemcginty1   en      human
# 24               Just been paid today and still skint 🤣🤣🤣   en      human
# 25          @glasgow_sophie 😭😭😭 I’ll put a bet on for u x   en      human
# 26                RT @rregaann: Skint is a understatement   en      human
# 27      RT @CaitlynLKing: Please RT.. if anybody sees ...   en      human
# 28             @_amylennie all that red bulls gettin to u   en      human
# 29      @_amylennie Well that was a bit pervy u big fr...   en      human
# ...                                                   ...  ...        ...
# 411870  RT @maurice_ace: @OlaEmdin Answer is because N...   en      human
# 411871  I'm just glad @osi_suave has helped too many p...   en      human
# 411872  Another PR/manager who collects money from art...   en      human
# 411873  Upgraded my ringtone from Ye to Gbona as it sh...   en      human
# 411874  RT @rollybello: This was last year at Eyinni G...   en      human
# 411875  What exactly has the AU achieved in strengthen...   en      human
# 411876  This whole getting a visa to go to Tanzania ha...   en      human
# 411877                                  Praiz - Shomolele   en      human
# 411878  RT @burnaboy: Burna Boy - Gbona (Official Musi...   en      human
# 411879  RT @NoTengoElJugo_: I bet the oxygen there CRI...   en      human
# 411880              Calvin Harris Ft Sam Smith - Promises   en      human
# 411881             RT @kae_y: !!! https://t.co/gl1Bgq9OsA   en      human
# 411882                 RT @cyberrboi: @OlaEmdin Dont dull   en      human
# 411883  RT @maurice_ace: @OlaEmdin Sharp sharp babes n...   en      human
# 411884  RT @MojiDelanoBlog: #FreeBhadoosky: Nigerians ...   en      human
# 411885  Sometimes I feel like I should reconsider this...   en      human
# 411886  RT @MosJollof: We also take orders from 20 pla...   en      human
# 411887  RT @MosJollof: Call and order for your firewoo...   en      human
# 411888  RT @adetutuoj8811: She has followed me on Inst...   en      human
# 411889  This country is about to experience the worst ...   en      human
# 411890  I've been seeing this tweet all day. Lol https...   en      human
# 411891  RT @Deekachy_md: We just lost my friend's mom ...   en      human
# 411892    @jarule147 Seen his new video? It's right there   en      human
# 411893  In my two years of running @MosJollof, this is...   en      human
# 411894  Thick skin should be the only thing required t...   en      human
# 411895  RT @ItsBollyLomo: Btw @MosJollof makes one of ...   en      human
# 411896                      Inauguration day in a bit...😊   en      human
# 411897                The family God blessed me with....❤   en      human
# 411898  RT @sam_adeyemi: This week, you will attract r...   en      human
# 411899  @cyberrboi @ShowDemCamp @MosJollof @MNLNDBlock...   en      human
#
#            sex
# 0       female
# 1       female
# 2       female
# 3       female
# 4       female
# 5       female
# 6       female
# 7       female
# 8       female
# 9       female
# 10      female
# 11      female
# 12      female
# 13      female
# 14      female
# 15      female
# 16      female
# 17      female
# 18      female
# 19      female
# 20      female
# 21      female
# 22      female
# 23      female
# 24      female
# 25      female
# 26      female
# 27      female
# 28      female
# 29      female
# ...        ...
# 411870  female
# 411871  female
# 411872  female
# 411873  female
# 411874  female
# 411875  female
# 411876  female
# 411877  female
# 411878  female
# 411879  female
# 411880  female
# 411881  female
# 411882  female
# 411883  female
# 411884  female
# 411885  female
# 411886  female
# 411887  female
# 411888  female
# 411889  female
# 411890  female
# 411891  female
# 411892  female
# 411893  female
# 411894  female
# 411895  female
# 411896  female
# 411897  female
# 411898  female
# 411899  female
#
# [206000 rows x 5 columns]

# %%
pathEn = '/Volumes/MacPassport/PycharmProjects/botOrNot/genHuman/en'
import time

# Creating empty dataframe
dataEn2 = pd.DataFrame()

# Monitoring time to load the files
start = time.time()

for root, dirs, files in os.walk(pathEn):
    for file in files:
        if file == 'truth.csv':
            continue
        else: 
            try:
                pathToFile = root + '/' + file # Creating path
                # print(pathToFile) # Just for debugging
                xml_data = open(pathToFile, "r", encoding="utf8") # Opening the text file
               
                etree = ET.parse(xml_data) # Create an ElementTree object
                
                data = list(iter_docs(etree.getroot())) # Create a list of dictionaries with the data
                filename = file.split(".")[0] # Get filename
                for dictionary in data: # Loop through the dictionary
                    dictionary['ID'] = filename # Append filename
                dataEn2 = dataEn2.append(data)  # Append the list of dictionary to a pandas dataframe
                
            # If the file is not valid, skip it
            except ValueError as e:
                print(e)
                continue
            
end = time.time()
print("Total running time is", end - start)
# Out:
# Total running time is 21.623064041137695

# %%
pathToLabels = "/Volumes/MacPassport/PycharmProjects/botOrNot/genHuman/en/truth.csv"

# %%
target = pd.read_csv(pathToLabels, sep=":::", header = None)
target.columns=['ID', 'botOrHuman', 'sex']
# Out:
# /Users/kram/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
mergedEnData2 = pd.merge(dataEn2, target, on='ID')

# %%
mergedEnData2
# Out:
#         ID                                               data lang botOrHuman  \
# 0       0m  @NardaGraham The lobby infrastructure for econ...   en      human
# 1       0m  @Trojan_Golf_ We were halfway committed.  We d...   en      human
# 2       0m  @LuigiBlood I voted "why must we suffer" but I...   en      human
# 3       0m  https://t.co/dSu2wBwnUF Musician Spotlight Mar...   en      human
# 4       0m  Your Current situation is “the small picture”....   en      human
# 5       0m  Now watching, Rawhead Rex (1986). Kino Lorber ...   en      human
# 6       0m  Trump won't be bragging about the economy toda...   en      human
# 7       0m  Just posted a photo @ Billy Jeans Denim Worksh...   en      human
# 8       0m  @MikeLoweReports @Chicago_Police @WGNNews @WGN...   en      human
# 9       0m  Except for Jesus, there isn’t a person that’s ...   en      human
# 10      0m  Whoever pays more than 140$/oz is retarded lol...   en      human
# 11      0m  Mardi Gras is over so I guess I have to go bac...   en      human
# 12      0m  @KamalaHarris Hey call your Dad. I heard Trump...   en      human
# 13      0m  #TulsiTownHall Are you a capitalist or not? If...   en      human
# 14      0m  In total #VibeCentral #JamSession right now......   en      human
# 15      0m  @Doctrine_Man It looks like he only found the ...   en      human
# 16      0m  Space show about how humans are awful and they...   en      human
# 17      0m  @Nothercupacafe I believe the degrees of that ...   en      human
# 18      0m  @LouDobbs MOST SERIOUS LIBERTARIANS UNDERSTAND...   en      human
# 19      0m  @DocThompsonShow @realBradStaggs @RealRonPhill...   en      human
# 20      0m  @GraceVanderWaal We often lose sight of the ol...   en      human
# 21      0m  @KrissyHimes @EdKrassen No argument about Trum...   en      human
# 22      0m  With the @Padres snagging #MannyMachado early ...   en      human
# 23      0m  @Spider_Duke If you think about it...Crippling...   en      human
# 24      0m  Feeling so good and finally living my Peachy c...   en      human
# 25      0m  When you go to order a @puttoutgolf mirror fro...   en      human
# 26      0m  @JussieSmollett I call BS, you pathetic little...   en      human
# 27      0m  This K.Cole girl really been stepping on our n...   en      human
# 28      0m  @OfficialPJNorth @CMThot20 @CMT @CountryMusic ...   en      human
# 29      0m  Whataboutism has poisoned y’alls ability to th...   en      human
# ...     ..                                                ...  ...        ...
# 199970  9w  @SALUTETRUMP @PowerTaking @wrenchhead2977 @Abb...   en      human
# 199971  9w  A new workshop comes your way! Maia Horvath wi...   en      human
# 199972  9w  @katmarie2014 Because I wasn’t driving myself ...   en      human
# 199973  9w  @SpeakerPelosi is finished. These three new b*...   en      human
# 199974  9w  shout out to the person who hit my car tonight...   en      human
# 199975  9w  @Diddy #JessiVMusic invites you to come watch ...   en      human
# 199976  9w  @AidenWolfe Exactly!  I couldn't put it into w...   en      human
# 199977  9w  @skyessong She is an an attention junkie willi...   en      human
# 199978  9w  Mentally trying to convince myself it’s not th...   en      human
# 199979  9w  @jonnnnylungz Yeah and how punk ass Waitr got ...   en      human
# 199980  9w  So what? We should feel sorry for this traitor...   en      human
# 199981  9w  @OfficialBrianaB maybe this is your next cover...   en      human
# 199982  9w  Las caras que pongo cuando comienza cada canci...   en      human
# 199983  9w  The idea was that to the degree that we have k...   en      human
# 199984  9w  I had to share this one mostly for @jerushatan...   en      human
# 199985  9w  I thought Wilson- Raybould told her story last...   en      human
# 199986  9w  @aimes_sweethrt That’s the million dollar ques...   en      human
# 199987  9w  @duchp - Je viens de terminer Guy Rocher. Hâte...   en      human
# 199988  9w  @tombo_fc Does it make sense to kill no handcu...   en      human
# 199989  9w  Now they can’t call me the ashy white girl at ...   en      human
# 199990  9w  this girl i’m talking to just assumed i’m like...   en      human
# 199991  9w  @Tygerlylly So that's an S a K and a J all nex...   en      human
# 199992  9w  Goodnight @SashaBanksWWE!! Hope you see this! ...   en      human
# 199993  9w  Best of luck to my #1 girl at Herriman Drill t...   en      human
# 199994  9w  @VanHipp @RyanAFournier As the wife of a Vietn...   en      human
# 199995  9w  Você se lembra quando começou a fazer parte do...   en      human
# 199996  9w  Had a good time with these guys yesterday! @lo...   en      human
# 199997  9w  I just took notes in one sitting that are long...   en      human
# 199998  9w  After GRR 15k guess who took a nap.  #meandmys...   en      human
# 199999  9w  We're hiring in #Charlotte, NC! Click the link...   en      human
#
#            sex
# 0         male
# 1         male
# 2         male
# 3         male
# 4         male
# 5         male
# 6         male
# 7         male
# 8         male
# 9         male
# 10        male
# 11        male
# 12        male
# 13        male
# 14        male
# 15        male
# 16        male
# 17        male
# 18        male
# 19        male
# 20        male
# 21        male
# 22        male
# 23        male
# 24        male
# 25        male
# 26        male
# 27        male
# 28        male
# 29        male
# ...        ...
# 199970  female
# 199971  female
# 199972  female
# 199973  female
# 199974  female
# 199975  female
# 199976  female
# 199977  female
# 199978  female
# 199979  female
# 199980  female
# 199981  female
# 199982  female
# 199983  female
# 199984  female
# 199985  female
# 199986  female
# 199987  female
# 199988  female
# 199989  female
# 199990  female
# 199991  female
# 199992  female
# 199993  female
# 199994  female
# 199995  female
# 199996  female
# 199997  female
# 199998  female
# 199999  female
#
# [200000 rows x 5 columns]

# %%
#Creo le matrici

# %%
'''Creo la litsa degli ID, delle classi e dei tweets pr ogni ID'''

listaIds =[]
listaClasses = []
matrixTweets = []

for index, x in mergedEnData.iterrows():
    id = x['ID']
    if id not in listaIds:
        newList = list()
        newList.append(x[1])
        matrixTweets.append(newList)
        listaIds.append(id)
        listaClasses.append(x[4])
    else:
        ls = matrixTweets[listaIds.index(id)]
        ls.append(x[1])
        matrixTweets[listaIds.index(id)] = ls
        
print(len(listaIds))
# Out:
# 2060

# %%
listaIds2 =[]
listaClasses2 = []
matrixTweets2 = []

for index, x in mergedEnData2.iterrows():
    id = x['ID']
    if id not in listaIds2:
        newList = list()
        newList.append(x[1])
        matrixTweets2.append(newList)
        listaIds2.append(id)
        listaClasses2.append(x[4])
    else:
        ls = matrixTweets2[listaIds2.index(id)]
        ls.append(x[1])
        matrixTweets2[listaIds2.index(id)] = ls
        
print(len(listaIds2))
print(len(matrixTweets2))
# Out:
# 2000
# 2000

# %%
from ekphrasis.dicts.emoticons import emoticons
from ekphrasis.classes.preprocessor import TextPreProcessor
from ekphrasis.classes.tokenizer import SocialTokenizer

text_processor = TextPreProcessor (
    # terms that will be normalized
    normalize=[ 'email' , 'percent' , 'money' , 'phone' ,
                'time' , 'url' , 'date' , 'number' ] ,
    fix_html=True ,  # fix HTML tokens
    segmenter="twitter" ,
    corrector="twitter" ,
    unpack_hashtags=True ,  # perform word segmentation on hashtags
    unpack_contractions=True ,  # Unpack contractions (can't -> can not)
    spell_correct_elong=True ,  # spell correction for elongated words
    tokenizer=SocialTokenizer(lowercase=True).tokenize,
    dicts=[ emoticons ]
)
# Out:
# Reading twitter - 1grams ...
# Reading twitter - 2grams ...
# Reading twitter - 1grams ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(matrixTweets, listaClasses, test_size = 0.15, random_state=72753)

# %%
import numpy as np
X_train = np.concatenate([X_train,matrixTweets2])
y_train = np.concatenate([y_train,listaClasses2])

# %%
len(X_train)
len(y_train)
# Out:
# 3751

# %%
import gensim
google_300 = gensim.models.KeyedVectors.load_word2vec_format("/Volumes/MacPassport/PycharmProjects/crawl-300d-2M-subword/crawl-300d-2M-subword.vec")

# %%
from nltk.tokenize import TweetTokenizer as TweetTokenizer
from nltk.corpus import stopwords
import random as rn
stop_words = set(stopwords.words('english'))
i = 0
matrixTweetsEmb_train = []
for tweetsUser in X_train:
    embTweetsUser = []
    if(i % 100) == 0:
         print(i)
    for tweet in tweetsUser:
        embTweetUser = np.zeros([50,300])
        #Preprocesso
        tokList = text_processor.pre_process_doc(tweet)
        #Rimuovo le stopwords
        tokList = [w for w in tokList if not w in stop_words]
        #trovo l'embedding
        numTok = 0;
        for token in tokList[0:50]:
            g_vec =[]
            is_in_model = False
            if token in google_300.vocab.keys ( ):
                is_in_model = True
                g_vec = google_300.word_vec(token)
            elif token == "<number>":
                is_in_model = True
                g_vec = google_300.word_vec( "number")
            elif token == "<percent>":
                is_in_model = True
                g_vec = google_300.word_vec("percent")
            elif token == "<money>":
                is_in_model = True
                g_vec = google_300.word_vec("money")
            elif token == "<email>":
                is_in_model = True
                g_vec = google_300.word_vec("email")
            elif token == "<phone>":
                is_in_model = True
                g_vec = google_300.word_vec("phone")
            elif token == "<time>":
                is_in_model = True
                g_vec = google_300.word_vec("time")
            elif token == "<date>":
                is_in_model = True
                g_vec = google_300.word_vec("date")
            elif token == "<url>":
                is_in_model = True
                g_vec = google_300.word_vec("url")
            elif not is_in_model:
                max = len ( google_300.vocab.keys ( ) ) - 1
                index = rn.randint ( 0 , max )
                word = google_300.index2word[ index ]
                g_vec = google_300.word_vec( word )

            embTweetUser[numTok] = np.array(g_vec)
            numTok += 1
        embTweetsUser.append(np.array(embTweetUser))
    i +=1
    matrixTweetsEmb_train.append(np.array(embTweetsUser))
matrixTweetsEmb_train = np.array(matrixTweetsEmb_train)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700

# %%
i = 0
matrixTweetsEmb_test = []
for tweetsUser in X_test:
    embTweetsUser = []
    if(i % 100) == 0:
         print(i)
    for tweet in tweetsUser:
        embTweetUser = np.zeros([50,300])
        #Preprocesso
        tokList = text_processor.pre_process_doc(tweet)
        #Rimuovo le stopwords
        tokList = [w for w in tokList if not w in stop_words]
        #trovo l'embedding
        numTok = 0;
        for token in tokList[0:50]:
            g_vec =[]
            is_in_model = False
            if token in google_300.vocab.keys ( ):
                is_in_model = True
                g_vec = google_300.word_vec(token)
            elif token == "<number>":
                is_in_model = True
                g_vec = google_300.word_vec( "number")
            elif token == "<percent>":
                is_in_model = True
                g_vec = google_300.word_vec("percent")
            elif token == "<money>":
                is_in_model = True
                g_vec = google_300.word_vec("money")
            elif token == "<email>":
                is_in_model = True
                g_vec = google_300.word_vec("email")
            elif token == "<phone>":
                is_in_model = True
                g_vec = google_300.word_vec("phone")
            elif token == "<time>":
                is_in_model = True
                g_vec = google_300.word_vec("time")
            elif token == "<date>":
                is_in_model = True
                g_vec = google_300.word_vec("date")
            elif token == "<url>":
                is_in_model = True
                g_vec = google_300.word_vec("url")
            elif not is_in_model:
                max = len ( google_300.vocab.keys ( ) ) - 1
                index = rn.randint ( 0 , max )
                word = google_300.index2word[ index ]
                g_vec = google_300.word_vec( word )

            embTweetUser[numTok] = np.array(g_vec)
            numTok += 1
        embTweetsUser.append(np.array(embTweetUser))
    i +=1
    matrixTweetsEmb_test.append(np.array(embTweetsUser))
matrixTweetsEmb_test = np.array(matrixTweetsEmb_test)
# Out:
# 0
# 100
# 200
# 300

# %%
from keras.layers import *
from keras.models import Sequential
model = Sequential()
model.add(Conv2D(200,(5,5), activation ='relu', input_shape=(100,50,300)))
model.add(MaxPool2D(2,2))
model.add(Conv2D(100,(5,4), activation ='relu'))
model.add(MaxPool2D(2,2))
model.add(Conv2D(20,(3,3), activation ='relu'))
model.add(MaxPool2D(2,2))
model.add(Flatten())
model.add(Dense(400, activation="tanh"))
model.add(Dense(200, activation="tanh"))
model.add(Dense(100, activation="tanh"))
model.add(Dense(2, activation="softmax"))
model.summary()
# Out:
# /Users/kram/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 96, 46, 200)       1500200
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 48, 23, 200)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 44, 20, 100)       400100
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 10, 100)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 8, 20)         18020
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 4, 20)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 800)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 400)               320400
# _________________________________________________________________
# dense_2 (Dense)              (None, 200)               80200
# _________________________________________________________________
# dense_3 (Dense)              (None, 100)               20100
# _________________________________________________________________
# dense_4 (Dense)              (None, 2)                 202
# =================================================================
# Total params: 2,339,222
# Trainable params: 2,339,222
# Non-trainable params: 0
# _________________________________________________________________

# %%
import category_encoders as ce
le =  ce.OneHotEncoder(return_df=False, impute_missing=False, handle_unknown="ignore")
training_classes = le.fit_transform(y_train)
test_classes = le.transform(y_test)
print(le.category_mapping)
# Out:
# [{'col': 0, 'mapping': [('female', 1), ('male', 2)]}]

# %%
from  sklearn.metrics  import classification_report
from keras.callbacks import Callback
class MyCallBack(Callback):
    def __init__(self,verbose=0):

        super(Callback, self).__init__()
        self.verbose = verbose

    def on_epoch_end(self, epoch, logs={}):
        current = logs.get('val_loss')
        # if current < 0.014:
        #     self.model.stop_training = True

        predicted = model.predict( matrixTweetsEmb_test )

        test = [ '0' ] * len ( X_test )
        i = 0
        for cl in predicted:
            test[ i ] = str ( np.argmax ( cl ) )
            i += 1

        test_lab = [ '0' ] * len ( X_test )
        i = 0
        for cl in test_classes:
            test_lab[ i ] = str ( np.argmax ( cl ) )
            i += 1

        print ( len ( X_test ) )
        print ( classification_report ( test , test_lab, digits=5 ) )

# %%
from keras.callbacks import ModelCheckpoint
filepath="/Volumes/MacPassport/PycharmProjects/botOrNot/weights.{epoch:02d}-{val_loss:.5f}_fasttext_female_male.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

# %%
callbacks_list = [
    checkpoint,
    MyCallBack(verbose=1)
]

# %%
model.compile ( loss='categorical_crossentropy' , optimizer='adam' , metrics=['accuracy'] )

history = model.fit(matrixTweetsEmb_train,training_classes,batch_size=128,epochs=3,
                      validation_data= (matrixTweetsEmb_test,test_classes) ,
                      callbacks=callbacks_list,
                      verbose=1)
# Out:
# Train on 3751 samples, validate on 309 samples
# Epoch 1/3
# 3751/3751 [==============================] - 1687s 450ms/step - loss: 0.4550 - acc: 0.8768 - val_loss: 0.4893 - val_acc: 0.7670
#
# Epoch 00001: val_acc did not improve from 0.84790
# 309
#              precision    recall  f1-score   support
#
#           0    0.70270   0.78788   0.74286       132
#           1    0.82609   0.75141   0.78698       177
#
# avg / total    0.77338   0.76699   0.76813       309
#
# Epoch 2/3
# 3751/3751 [==============================] - 1711s 456ms/step - loss: 0.0389 - acc: 0.9936 - val_loss: 0.5660 - val_acc: 0.8414
#
# Epoch 00002: val_acc did not improve from 0.84790
# 309
#              precision    recall  f1-score   support
#
#           0    0.85811   0.81935   0.83828       155
#           1    0.82609   0.86364   0.84444       154
#
# avg / total    0.84215   0.84142   0.84135       309
#
# Epoch 3/3
# 3751/3751 [==============================] - 1627s 434ms/step - loss: 0.0020 - acc: 1.0000 - val_loss: 0.6679 - val_acc: 0.8382
#
# Epoch 00003: val_acc did not improve from 0.84790
# 309
#              precision    recall  f1-score   support
#
#           0    0.82432   0.83562   0.82993       146
#           1    0.85093   0.84049   0.84568       163
#
# avg / total    0.83836   0.83819   0.83824       309

# %%
# Out:
# array(['female', 'female', 'male', ..., 'female', 'male', 'female'],
#       dtype='<U6')
